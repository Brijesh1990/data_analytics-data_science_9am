# %%
# operator examples
a=True
b=False
print(a)
print(b)
print(type(a))
# Out:
# True
# False
# <class 'bool'>

# %%
# examples of string 
str1='brijesh'
str2="karan"
res=str1 + "\n" + str2
print(res)
# Out:
# brijesh
# karan

# %%
str1=10
str2=int("20") # convert string to ineteger
res=str1 + str2
print(res)
# Out:
# 30

# %%
# w.a.p to print your name take input from users
# input() is an ingult method that can be used to take input from users 

str=input("Enter your name :")
print("Your name is :",str)
# Out:
# Enter your name : jaydeep
# Your name is : jaydeep

# %%
# simple interest 

principle=int(input("Enter your principle ammount :"))
interest=int(input("Enter your given Interest :"))
years=int(input("Enter your numbers of years :"))
# si=p*n*r/100 
result=principle*years*interest/100
print("Total interest you have to paid of :",result)
# Out:
# Enter your principle ammount : 50000
# Enter your given Interest : 5
# Enter your numbers of years : 0.6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       3 principle=int(input("Enter your principle ammount :"))
#       4 interest=int(input("Enter your given Interest :"))
# ----> 5 years=int(input("Enter your numbers of years :"))
#       6 # si=p*n*r/100
#       7 result=principle*years*interest/100
#
# ValueError: invalid literal for int() with base 10: '0.6'

# %%
# simple interest 

principle=float(input("Enter your principle ammount :"))
interest=float(input("Enter your given Interest :"))
years=float(input("Enter your numbers of years :"))
# si=p*n*r/100 
result=principle*years*interest/100
print("Total interest you have to paid of :",result)

# %%
# how to find square of numbers
num1=2
num2=2
res=num1*num2
print(res)
# Out:
# 4

# %%
# how to find square of numbers take input from users
number=int(input("Enter a Numbers :"))
print("The square of numbers is :",number*4)
# Out:
# Enter a Numbers : 8
# The square of numbers is : 32

# %%
# how to find square of numbers take input from users
number=int(input("Enter a Numbers :"))
print("The square of numbers is :",pow(number,2))
# Out:
# Enter a Numbers : 2
# The square of numbers is : 4

# %%
# how to find square of numbers take input from users
number=int(input("Enter a Numbers :"))
print("The square of numbers is :",pow(number,3))
# Out:
# Enter a Numbers : 4
# The square of numbers is : 64
